# %%
# !pip install --upgrade --force-reinstall scikit-learn==1.0.0 --quiet
# !pip install --upgrade lightgbm==3.2.1 --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.21.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, RepeatedKFold
from sklearn.metrics import mean_squared_error

import lightgbm as lgb

from tqdm.auto import tqdm

# %%
class Config:
    SEED = 3655

    N_SPLITS = 5
    N_REPEATS = 2

    EARLY_STOPPING_ROUNDS = 50
    VERBOSE_EVAL = 100

    MODEL_PARAMS = {
        'metric': 'rmse',

        'boosting': 'gbdt',

        "linear_tree": True,

        'num_leaves': 32,
        'learning_rate': 0.1,
        'max_depth': 8,
        'tree_learner': 'voting',
        'verbose': 1,
        'n_jobs': -1,
        }

    TRAIN_PARAMS = {
        'num_boost_round': 1_000
        }

# %%
data = fetch_california_housing()

X = pd.DataFrame(data=data['data'], columns=data['feature_names'])
y = data['target']
feature_names = data['feature_names']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=.8, test_size=.2, random_state=Config.SEED)

train_dataset = lgb.Dataset(
    data=X_train,
    label=y_train,
    feature_name=feature_names
)

valid_dataset = lgb.Dataset(
    data=X_valid,
    label=y_valid,
    feature_name=feature_names
)

# %%
es = lgb.callback.early_stopping(stopping_rounds=Config.EARLY_STOPPING_ROUNDS)
log_eval = lgb.callback.print_evaluation(period=Config.VERBOSE_EVAL)

model = lgb.train(
    params=Config.MODEL_PARAMS, 
    train_set=train_dataset, 
    valid_sets=[train_dataset, valid_dataset], 
    valid_names=['train', 'valid'], 
    callbacks=[
               es,
               log_eval
               ],
    **Config.TRAIN_PARAMS
    )
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001413 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1838
# [LightGBM] [Info] Number of data points in the train set: 16512, number of used features: 8
# [LightGBM] [Info] Start training from score 2.064059
# [1]	train's rmse: 1.07415	valid's rmse: 1.09765
# Training until validation scores don't improve for 50 rounds
# [2]	train's rmse: 1.00337	valid's rmse: 1.02533
# [3]	train's rmse: 0.939754	valid's rmse: 0.96051
# [4]	train's rmse: 0.880569	valid's rmse: 0.900256
# [5]	train's rmse: 0.831001	valid's rmse: 0.850012
# [6]	train's rmse: 0.787256	valid's rmse: 0.805869
# [7]	train's rmse: 0.749011	valid's rmse: 0.767588
# [8]	train's rmse: 0.716512	valid's rmse: 0.735781
# [9]	train's rmse: 0.688826	valid's rmse: 0.708487
# [10]	train's rmse: 0.664918	valid's rmse: 0.685564
# [11]	train's rmse: 0.642954	valid's rmse: 0.664714
# [12]	train's rmse: 0.622934	valid's rmse: 0.645134
# [13]	train's rmse: 0.605953	valid's rmse: 0.629209
# [14]	train's rmse: 0.590942	valid's rmse: 0.615041
# [15]	train's rmse: 0.577231	valid's rmse: 0.602453
# [16]	train's rmse: 0.564937	valid's rmse: 0.591728
# [17]	train's rmse: 0.55415	valid's rmse: 0.58189
# [18]	train's rmse: 0.545098	valid's rmse: 0.574607
# [19]	train's rmse: 0.536918	valid's rmse: 0.566939
# [20]	train's rmse: 0.526047	valid's rmse: 0.557378
# [21]	train's rmse: 0.518131	valid's rmse: 0.550686
# [22]	train's rmse: 0.51153	valid's rmse: 0.544337
# [23]	train's rmse: 0.504375	valid's rmse: 0.538116
# [24]	train's rmse: 0.498186	valid's rmse: 0.532338
# [25]	train's rmse: 0.492953	valid's rmse: 0.527991
# [26]	train's rmse: 0.487839	valid's rmse: 0.523803
# [27]	train's rmse: 0.483322	valid's rmse: 0.518861
# [28]	train's rmse: 0.478931	valid's rmse: 0.516189
# [29]	train's rmse: 0.474207	valid's rmse: 0.512752
# [30]	train's rmse: 0.470825	valid's rmse: 0.509988
# [31]	train's rmse: 0.467317	valid's rmse: 0.507122
# [32]	train's rmse: 0.464122	valid's rmse: 0.505754
# [33]	train's rmse: 0.460762	valid's rmse: 0.504303
# [34]	train's rmse: 0.457949	valid's rmse: 0.502077
# [35]	train's rmse: 0.455385	valid's rmse: 0.500547
# [36]	train's rmse: 0.453042	valid's rmse: 0.499401
# [37]	train's rmse: 0.450785	valid's rmse: 0.498512
# [38]	train's rmse: 0.447705	valid's rmse: 0.496233
# [39]	train's rmse: 0.446243	valid's rmse: 0.496504
# [40]	train's rmse: 0.444092	valid's rmse: 0.49928
# [41]	train's rmse: 0.441951	valid's rmse: 0.497299
# [42]	train's rmse: 0.439468	valid's rmse: 0.495445
# [43]	train's rmse: 0.437617	valid's rmse: 0.494732
# [44]	train's rmse: 0.435815	valid's rmse: 0.494264
# [45]	train's rmse: 0.434229	valid's rmse: 0.494403
# [46]	train's rmse: 0.431326	valid's rmse: 0.492009
# [47]	train's rmse: 0.429723	valid's rmse: 0.49166
# [48]	train's rmse: 0.427113	valid's rmse: 0.489574
# [49]	train's rmse: 0.425429	valid's rmse: 0.488954
# [50]	train's rmse: 0.423504	valid's rmse: 0.487306
# [51]	train's rmse: 0.4216	valid's rmse: 0.486189
# [52]	train's rmse: 0.420215	valid's rmse: 0.485911
# [53]	train's rmse: 0.418653	valid's rmse: 0.485151
# [54]	train's rmse: 0.417342	valid's rmse: 0.484773
# [55]	train's rmse: 0.415081	valid's rmse: 0.483502
# [56]	train's rmse: 0.41385	valid's rmse: 0.483272
# [57]	train's rmse: 0.412719	valid's rmse: 0.482988
# [58]	train's rmse: 0.411728	valid's rmse: 0.482527
# [59]	train's rmse: 0.410161	valid's rmse: 0.482059
# [60]	train's rmse: 0.408839	valid's rmse: 0.481089
# [61]	train's rmse: 0.407501	valid's rmse: 0.480313
# [62]	train's rmse: 0.405956	valid's rmse: 0.479426
# [63]	train's rmse: 0.404936	valid's rmse: 0.479257
# [64]	train's rmse: 0.403512	valid's rmse: 0.478695
# [65]	train's rmse: 0.402467	valid's rmse: 0.478566
# [66]	train's rmse: 0.40111	valid's rmse: 0.47755
# [67]	train's rmse: 0.399781	valid's rmse: 0.47711
# [68]	train's rmse: 0.398808	valid's rmse: 0.477017
# [69]	train's rmse: 0.397102	valid's rmse: 0.475991
# [70]	train's rmse: 0.396043	valid's rmse: 0.476144
# [71]	train's rmse: 0.394887	valid's rmse: 0.47529
# [72]	train's rmse: 0.393709	valid's rmse: 0.47485
# [73]	train's rmse: 0.391902	valid's rmse: 0.474002
# [74]	train's rmse: 0.390755	valid's rmse: 0.473535
# [75]	train's rmse: 0.389368	valid's rmse: 0.472845
# [76]	train's rmse: 0.433649	valid's rmse: 0.74899
# [77]	train's rmse: 0.430651	valid's rmse: 0.748943
# [78]	train's rmse: 0.42782	valid's rmse: 0.751314
# [79]	train's rmse: 0.425296	valid's rmse: 0.750752
# [80]	train's rmse: 0.423581	valid's rmse: 0.755541
# [81]	train's rmse: 0.420566	valid's rmse: 0.755099
# [82]	train's rmse: 0.41827	valid's rmse: 0.754996
# [83]	train's rmse: 0.416893	valid's rmse: 0.755328
# [84]	train's rmse: 0.414679	valid's rmse: 0.754142
# [85]	train's rmse: 0.413647	valid's rmse: 0.753799
# [86]	train's rmse: 0.411033	valid's rmse: 0.780212
# [87]	train's rmse: 0.409858	valid's rmse: 0.755274
# [88]	train's rmse: 0.409034	valid's rmse: 0.755082
# [89]	train's rmse: 0.407643	valid's rmse: 0.752135
# [90]	train's rmse: 0.406071	valid's rmse: 0.752346
# [91]	train's rmse: 0.406145	valid's rmse: 0.769912
# [92]	train's rmse: 0.405128	valid's rmse: 0.769923
# [93]	train's rmse: 0.403319	valid's rmse: 0.767476
# [94]	train's rmse: 0.40168	valid's rmse: 0.836748
# [95]	train's rmse: 0.400765	valid's rmse: 0.80159
# [96]	train's rmse: 0.39957	valid's rmse: 0.800662
# [97]	train's rmse: 0.397081	valid's rmse: 0.800431
# [98]	train's rmse: 0.396157	valid's rmse: 0.800267
# [99]	train's rmse: 0.395411	valid's rmse: 0.801163
# [100]	train's rmse: 0.393791	valid's rmse: 0.928027
# [100]	train's rmse: 0.393791	valid's rmse: 0.928027
# [101]	train's rmse: 0.392823	valid's rmse: 0.963199
# [102]	train's rmse: 0.391213	valid's rmse: 0.768854
# [103]	train's rmse: 0.390163	valid's rmse: 0.794992
# [104]	train's rmse: 0.389144	valid's rmse: 0.826083
# [105]	train's rmse: 0.388126	valid's rmse: 0.828767
# [106]	train's rmse: 0.387066	valid's rmse: 0.828469
# [107]	train's rmse: 0.386321	valid's rmse: 0.828244
# [108]	train's rmse: 0.385448	valid's rmse: 0.828066
# [109]	train's rmse: 0.383983	valid's rmse: 0.830913
# [110]	train's rmse: 0.383378	valid's rmse: 0.831504
# [111]	train's rmse: 0.382381	valid's rmse: 0.831247
# [112]	train's rmse: 0.381757	valid's rmse: 0.830591
# [113]	train's rmse: 0.380853	valid's rmse: 0.830511
# [114]	train's rmse: 0.380157	valid's rmse: 0.83052
# [115]	train's rmse: 0.378953	valid's rmse: 0.830154
# [116]	train's rmse: 0.378006	valid's rmse: 0.829853
# [117]	train's rmse: 0.37716	valid's rmse: 0.82885
# [118]	train's rmse: 0.376331	valid's rmse: 0.828309
# [119]	train's rmse: 0.375096	valid's rmse: 0.828057
# [120]	train's rmse: 0.373814	valid's rmse: 0.822788
# [121]	train's rmse: 0.373209	valid's rmse: 1.09042
# [122]	train's rmse: 0.372621	valid's rmse: 1.09029
# [123]	train's rmse: 0.371916	valid's rmse: 1.03114
# [124]	train's rmse: 0.37107	valid's rmse: 1.03111
# [125]	train's rmse: 0.36968	valid's rmse: 1.03128
# Early stopping, best iteration is:
# [75]	train's rmse: 0.389368	valid's rmse: 0.472845
