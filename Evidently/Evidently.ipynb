# %%
# !pip install --upgrade evidently --quiet
# Out:
#      |████████████████████████████████| 22.1 MB 1.5 MB/s
#      |████████████████████████████████| 9.8 MB 58.3 MB/s
#      |████████████████████████████████| 38.1 MB 1.4 MB/s
#      |████████████████████████████████| 636 kB 43.3 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

from evidently.dashboard import Dashboard
from evidently.dashboard.tabs import (
    DataDriftTab,
    CatTargetDriftTab
)

iris = datasets.load_iris()
iris_frame = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_frame['target'] = iris.target

# %%
train_df, valid_df = train_test_split(iris_frame, test_size=.2, train_size=.8, random_state=42, stratify=iris_frame["target"])

# %%
iris_data_drift_report = Dashboard(tabs=[DataDriftTab()])
# iris_data_drift_report.calculate(iris_frame[:100], iris_frame[100:], column_mapping = None)
iris_data_drift_report.calculate(train_df, valid_df, column_mapping = None)

# iris_data_drift_report.save("reports/my_report.html")
iris_data_drift_report.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
iris_data_and_target_drift_report = Dashboard(tabs=[DataDriftTab(), CatTargetDriftTab()])
# iris_data_and_target_drift_report.calculate(iris_frame[:100], iris_frame[100:], column_mapping = None)
iris_data_and_target_drift_report.calculate(train_df, valid_df, column_mapping = None)

# iris_data_and_target_drift_report.save("reports/my_report_with_2_tabs.html")
iris_data_and_target_drift_report.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from evidently.model_profile import Profile
from evidently.model_profile.sections import (
    DataDriftProfileSection,
    CatTargetDriftProfileSection
)

# %%
iris_data_drift_profile = Profile(sections=[DataDriftProfileSection()])
iris_data_drift_profile.calculate(iris_frame, iris_frame, column_mapping = None)
iris_data_drift_profile.json()
# Out:
# '{"data_drift": {"name": "data_drift", "datetime": "2022-03-02 07:26:53.490814", "data": {"utility_columns": {"date": null, "id": null, "target": "target", "prediction": null}, "cat_feature_names": [], "num_feature_names": ["petal length (cm)", "sepal length (cm)", "sepal width (cm)", "petal width (cm)"], "datetime_feature_names": [], "target_names": null, "options": {"confidence": 0.95, "drift_share": 0.5, "nbinsx": 10, "xbins": null}, "metrics": {"n_features": 4, "n_drifted_features": 0, "share_drifted_features": 0.0, "dataset_drift": false, "petal length (cm)": {"current_small_hist": [[0.4180790960451977, 0.14689265536723162, 0.0, 0.033898305084745776, 0.09039548022598871, 0.2937853107344629, 0.32768361581920913, 0.20338983050847462, 0.12429378531073448, 0.05649717514124295], [1.0, 1.59, 2.18, 2.7700000000000005, 3.3600000000000003, 3.95, 4.540000000000001, 5.130000000000001, 5.720000000000001, 6.3100000000000005, 6.9]], "ref_small_hist": [[0.4180790960451977, 0.14689265536723162, 0.0, 0.033898305084745776, 0.09039548022598871, 0.2937853107344629, 0.32768361581920913, 0.20338983050847462, 0.12429378531073448, 0.05649717514124295], [1.0, 1.59, 2.18, 2.7700000000000005, 3.3600000000000003, 3.95, 4.540000000000001, 5.130000000000001, 5.720000000000001, 6.3100000000000005, 6.9]], "feature_type": "num", "p_value": 1.0}, "sepal length (cm)": {"current_small_hist": [[0.16666666666666652, 0.4259259259259266, 0.259259259259259, 0.4999999999999995, 0.2962962962962968, 0.48148148148148107, 0.33333333333333304, 0.11111111111111129, 0.09259259259259252, 0.11111111111111102], [4.3, 4.66, 5.02, 5.38, 5.74, 6.1, 6.46, 6.82, 7.18, 7.54, 7.9]], "ref_small_hist": [[0.16666666666666652, 0.4259259259259266, 0.259259259259259, 0.4999999999999995, 0.2962962962962968, 0.48148148148148107, 0.33333333333333304, 0.11111111111111129, 0.09259259259259252, 0.11111111111111102], [4.3, 4.66, 5.02, 5.38, 5.74, 6.1, 6.46, 6.82, 7.18, 7.54, 7.9]], "feature_type": "num", "p_value": 1.0}, "sepal width (cm)": {"current_small_hist": [[0.11111111111111102, 0.19444444444444464, 0.6111111111111106, 0.6666666666666673, 1.027777777777777, 0.8611111111111103, 0.2777777777777775, 0.30555555555555586, 0.05555555555555561, 0.05555555555555551], [2.0, 2.24, 2.48, 2.72, 2.96, 3.2, 3.4400000000000004, 3.6800000000000006, 3.9200000000000004, 4.16, 4.4]], "ref_small_hist": [[0.11111111111111102, 0.19444444444444464, 0.6111111111111106, 0.6666666666666673, 1.027777777777777, 0.8611111111111103, 0.2777777777777775, 0.30555555555555586, 0.05555555555555561, 0.05555555555555551], [2.0, 2.24, 2.48, 2.72, 2.96, 3.2, 3.4400000000000004, 3.6800000000000006, 3.9200000000000004, 4.16, 4.4]], "feature_type": "num", "p_value": 1.0}, "petal width (cm)": {"current_small_hist": [[1.138888888888889, 0.22222222222222224, 0.02777777777777778, 0.19444444444444436, 0.22222222222222224, 0.9166666666666666, 0.16666666666666666, 0.638888888888889, 0.24999999999999975, 0.3888888888888893], [0.1, 0.33999999999999997, 0.58, 0.82, 1.06, 1.3, 1.54, 1.78, 2.02, 2.2600000000000002, 2.5]], "ref_small_hist": [[1.138888888888889, 0.22222222222222224, 0.02777777777777778, 0.19444444444444436, 0.22222222222222224, 0.9166666666666666, 0.16666666666666666, 0.638888888888889, 0.24999999999999975, 0.3888888888888893], [0.1, 0.33999999999999997, 0.58, 0.82, 1.06, 1.3, 1.54, 1.78, 2.02, 2.2600000000000002, 2.5]], "feature_type": "num", "p_value": 1.0}}}}, "timestamp": "2022-03-02 07:26:53.490988"}'

# %%
iris_target_and_data_drift_profile = Profile(sections=[DataDriftProfileSection(), CatTargetDriftProfileSection()])
iris_target_and_data_drift_profile.calculate(iris_frame[:75], iris_frame[75:], column_mapping = None) 
iris_target_and_data_drift_profile.json()
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:6707: RuntimeWarning:
#
# divide by zero encountered in true_divide
# '{"data_drift": {"name": "data_drift", "datetime": "2022-03-02 07:26:59.205620", "data": {"utility_columns": {"date": null, "id": null, "target": "target", "prediction": null}, "cat_feature_names": [], "num_feature_names": ["petal length (cm)", "sepal length (cm)", "sepal width (cm)", "petal width (cm)"], "datetime_feature_names": [], "target_names": null, "options": {"confidence": 0.95, "drift_share": 0.5, "nbinsx": 10, "xbins": null}, "metrics": {"n_features": 4, "n_drifted_features": 4, "share_drifted_features": 1.0, "dataset_drift": true, "petal length (cm)": {"current_small_hist": [[0.06837606837606836, 0.06837606837606836, 0.2051282051282053, 0.37606837606837556, 0.2735042735042737, 0.5470085470085474, 0.478632478632478, 0.34188034188034216, 0.06837606837606842, 0.13675213675213654], [3.0, 3.39, 3.7800000000000002, 4.17, 4.5600000000000005, 4.95, 5.34, 5.73, 6.12, 